# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import warnings
import seaborn as sns
import matplotlib.pyplot as plt

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Data Extraction

# %%
df = pd.read_csv(r"C:\Users\Lenovo\Intership\EDAIntership\data.xlsx - Sheet1.csv")
df
# Out:
#      Unnamed: 0      ID     Salary           DOJ           DOL  \
# 0         train  203097   420000.0   6/1/12 0:00       present
# 1         train  579905   500000.0   9/1/13 0:00       present
# 2         train  810601   325000.0   6/1/14 0:00       present
# 3         train  267447  1100000.0   7/1/11 0:00       present
# 4         train  343523   200000.0   3/1/14 0:00   3/1/15 0:00
# ...         ...     ...        ...           ...           ...
# 3993      train   47916   280000.0  10/1/11 0:00  10/1/12 0:00
# 3994      train  752781   100000.0   7/1/13 0:00   7/1/13 0:00
# 3995      train  355888   320000.0   7/1/13 0:00       present
# 3996      train  947111   200000.0   7/1/14 0:00   1/1/15 0:00
# 3997      train  324966   400000.0   2/1/13 0:00       present
#
#                       Designation           JobCity Gender           DOB  \
# 0         senior quality engineer         Bangalore      f  2/19/90 0:00
# ...

# %% [markdown]
# ### EDA

# %%
df.shape
# Out:
# (3998, 39)

# %%
df["Unnamed: 0"].unique()
# Out:
# array(['train'], dtype=object)

# %%
df["Unnamed: 0"].nunique()
# Out:
# 1

# %%
df.drop("Unnamed: 0", axis=1, inplace = True)

# %%
df.head()
# Out:
#        ID     Salary          DOJ          DOL               Designation  \
# 0  203097   420000.0  6/1/12 0:00      present   senior quality engineer
# 1  579905   500000.0  9/1/13 0:00      present         assistant manager
# 2  810601   325000.0  6/1/14 0:00      present          systems engineer
# 3  267447  1100000.0  7/1/11 0:00      present  senior software engineer
# 4  343523   200000.0  3/1/14 0:00  3/1/15 0:00                       get
#
#      JobCity Gender           DOB  10percentage  \
# 0  Bangalore      f  2/19/90 0:00          84.3
# 1     Indore      m  10/4/89 0:00          85.4
# 2    Chennai      f   8/3/92 0:00          85.0
# 3    Gurgaon      m  12/5/89 0:00          85.6
# 4    Manesar      m  2/27/91 0:00          78.0
#
#                           10board  ...  ComputerScience  MechanicalEngg  \
# 0  board ofsecondary education,ap  ...               -1              -1
# 1                            cbse  ...               -1              -1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3998 non-null   int64
#  1   Salary                 3998 non-null   float64
#  2   DOJ                    3998 non-null   object
#  3   DOL                    3998 non-null   object
#  4   Designation            3998 non-null   object
#  5   JobCity                3998 non-null   object
#  6   Gender                 3998 non-null   object
#  7   DOB                    3998 non-null   object
#  8   10percentage           3998 non-null   float64
#  9   10board                3998 non-null   object
#  10  12graduation           3998 non-null   int64
#  11  12percentage           3998 non-null   float64
#  12  12board                3998 non-null   object
#  13  CollegeID              3998 non-null   int64
# ...

# %%
df.isna().sum()
# Out:
# ID                       0
# Salary                   0
# DOJ                      0
# DOL                      0
# Designation              0
# JobCity                  0
# Gender                   0
# DOB                      0
# 10percentage             0
# 10board                  0
# 12graduation             0
# 12percentage             0
# 12board                  0
# CollegeID                0
# CollegeTier              0
# Degree                   0
# Specialization           0
# collegeGPA               0
# CollegeCityID            0
# CollegeCityTier          0
# CollegeState             0
# GraduationYear           0
# English                  0
# Logical                  0
# Quant                    0
# Domain                   0
# ComputerProgramming      0
# ElectronicsAndSemicon    0
# ComputerScience          0
# MechanicalEngg           0
# ElectricalEngg           0
# TelecomEngg              0
# CivilEngg                0
# conscientiousness        0
# ...

# %%
anlysis= pd.DataFrame({"Unique":df.nunique(),
                       "Null":df.isna().sum(),
                       "NullPercentage":df.isna().sum()/len(df),
                       "DataType":df.dtypes})
display(anlysis)
# Out:
#                        Unique  Null  NullPercentage DataType
# ID                       3998     0             0.0    int64
# Salary                    177     0             0.0  float64
# DOJ                        81     0             0.0   object
# DOL                        67     0             0.0   object
# Designation               419     0             0.0   object
# JobCity                   339     0             0.0   object
# Gender                      2     0             0.0   object
# DOB                      1872     0             0.0   object
# 10percentage              851     0             0.0  float64
# 10board                   275     0             0.0   object
# 12graduation               16     0             0.0    int64
# 12percentage              801     0             0.0  float64
# 12board                   340     0             0.0   object
# CollegeID                1350     0             0.0    int64
# ...

# %%
df.describe()
# Out:
#                  ID        Salary  10percentage  12graduation  12percentage  \
# count  3.998000e+03  3.998000e+03   3998.000000   3998.000000   3998.000000
# mean   6.637945e+05  3.076998e+05     77.925443   2008.087544     74.466366
# std    3.632182e+05  2.127375e+05      9.850162      1.653599     10.999933
# min    1.124400e+04  3.500000e+04     43.000000   1995.000000     40.000000
# 25%    3.342842e+05  1.800000e+05     71.680000   2007.000000     66.000000
# 50%    6.396000e+05  3.000000e+05     79.150000   2008.000000     74.400000
# 75%    9.904800e+05  3.700000e+05     85.670000   2009.000000     82.600000
# max    1.298275e+06  4.000000e+06     97.760000   2013.000000     98.700000
#
#           CollegeID  CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  \
# count   3998.000000  3998.000000  3998.000000    3998.000000      3998.000000
# mean    5156.851426     1.925713    71.486171    5156.851426         0.300400
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityID', 'CollegeCityTier', 'CollegeState', 'GraduationYear',
#        'English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism',
#        'openess_to_experience'],
#       dtype='object')

# %%
df['DOJ'].unique()
# Out:
# array(['6/1/12 0:00', '9/1/13 0:00', '6/1/14 0:00', '7/1/11 0:00',
#        '3/1/14 0:00', '8/1/14 0:00', '7/1/14 0:00', '7/1/13 0:00',
#        '4/1/11 0:00', '8/1/11 0:00', '12/1/13 0:00', '1/1/14 0:00',
#        '8/1/13 0:00', '9/1/14 0:00', '11/1/10 0:00', '8/1/12 0:00',
#        '10/1/13 0:00', '9/1/12 0:00', '1/1/11 0:00', '2/1/15 0:00',
#        '11/1/14 0:00', '12/1/11 0:00', '10/1/14 0:00', '1/1/15 0:00',
#        '3/1/13 0:00', '10/1/10 0:00', '1/1/13 0:00', '6/1/11 0:00',
#        '4/1/14 0:00', '5/1/12 0:00', '10/1/12 0:00', '4/1/15 0:00',
#        '3/1/12 0:00', '6/1/13 0:00', '9/1/09 0:00', '11/1/13 0:00',
#        '7/1/10 0:00', '2/1/14 0:00', '6/1/15 0:00', '5/1/14 0:00',
#        '12/1/14 0:00', '11/1/11 0:00', '7/1/15 0:00', '5/1/13 0:00',
#        '3/1/11 0:00', '3/1/15 0:00', '7/1/12 0:00', '10/1/11 0:00',
#        '4/1/10 0:00', '4/1/13 0:00', '12/1/10 0:00', '2/1/13 0:00',
#        '9/1/11 0:00', '2/1/12 0:00', '1/1/12 0:00', '12/1/12 0:00',
# ...

# %%
df['DOL'].unique()
# Out:
# array(['present', '3/1/15 0:00', '5/1/15 0:00', '7/1/15 0:00',
#        '4/1/15 0:00', '10/1/14 0:00', '9/1/14 0:00', '6/1/14 0:00',
#        '9/1/12 0:00', '12/1/13 0:00', '6/1/15 0:00', '10/1/13 0:00',
#        '1/1/15 0:00', '4/1/14 0:00', '6/1/13 0:00', '3/1/12 0:00',
#        '7/1/14 0:00', '2/1/13 0:00', '1/1/14 0:00', '4/1/13 0:00',
#        '7/1/12 0:00', '5/1/14 0:00', '9/1/13 0:00', '2/1/15 0:00',
#        '1/1/12 0:00', '8/1/15 0:00', '8/1/14 0:00', '12/1/15 0:00',
#        '12/1/14 0:00', '5/1/12 0:00', '3/1/11 0:00', '7/1/11 0:00',
#        '2/1/14 0:00', '12/1/11 0:00', '10/1/15 0:00', '11/1/14 0:00',
#        '3/1/14 0:00', '11/1/11 0:00', '5/1/13 0:00', '7/1/13 0:00',
#        '11/1/13 0:00', '1/1/11 0:00', '5/1/11 0:00', '2/1/12 0:00',
#        '11/1/12 0:00', '6/1/12 0:00', '8/1/13 0:00', '3/1/05 0:00',
#        '3/1/13 0:00', '10/1/12 0:00', '2/1/11 0:00', '2/1/10 0:00',
#        '1/1/13 0:00', '6/1/11 0:00', '9/1/15 0:00', '4/1/12 0:00',
# ...

# %%
for i in df.columns:
    print('*'*20,i,'*'*20)
    print(df[i].unique())
# Out:
# ******************** ID ********************
# [203097 579905 810601 ... 355888 947111 324966]
# ******************** Salary ********************
# [ 420000.  500000.  325000. 1100000.  200000.  300000.  400000.  600000.
#   230000.  450000.  270000.  350000.  250000.  120000.  320000.  190000.
#   180000.  335000.  435000.  345000.  145000.  220000.  530000.  340000.
#   360000.  215000.   80000.  330000.  380000.  110000.  205000.   95000.
#   390000.   60000.  240000.  525000.  305000.  150000.  310000.  455000.
#   800000.  100000.  280000.  445000.  315000.  370000.  275000. 1500000.
#   425000.  470000.  460000.  510000.  480000.  170000.  640000.  225000.
#   440000. 1200000.  675000.  105000.  195000.  385000.  235000.  615000.
#   290000.  140000.  405000. 1860000.  375000.  430000.  660000.   70000.
#   410000.  550000.   35000.  115000.  415000.  265000.  285000.  245000.
#   395000.  560000.  700000.  185000.  160000.  625000.   85000.  135000.
# ...

# %%
df["JobCity"].value_counts()
# Out:
# JobCity
# Bangalore           627
# -1                  461
# Noida               368
# Hyderabad           335
# Pune                290
#                    ...
# Tirunelvelli          1
# Ernakulam             1
# Nanded                1
# Dharmapuri            1
# Asifabadbanglore      1
# Name: count, Length: 339, dtype: int64

# %%
df.columns	=	df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityID', 'CollegeCityTier', 'CollegeState', 'GraduationYear',
#        'English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism',
#        'openess_to_experience'],
#       dtype='object')

# %% [markdown]
# ##### To remove and convert 'present' to present date

# %%
df["DOJ"]=pd.to_datetime(df["DOJ"]).dt.date
df["DOL"].replace("present",dt.datetime.today(),inplace=True)
df['DOL'] = pd.to_datetime(df['DOL']).dt.date

#to get the period of work in an organization
df['Period'] = pd.to_datetime(df["DOL"]).dt.year - pd.to_datetime(df['DOJ']).dt.year

# %%
##to get DOB year,so DOB column conversion from timestamp to year
df['DOB'] = pd.to_datetime(df['DOB']).dt.year
df.head(5)
# Out:
#        ID     Salary         DOJ         DOL               Designation  \
# 0  203097   420000.0  2012-06-01  2024-10-04   senior quality engineer
# 1  579905   500000.0  2013-09-01  2024-10-04         assistant manager
# 2  810601   325000.0  2014-06-01  2024-10-04          systems engineer
# 3  267447  1100000.0  2011-07-01  2024-10-04  senior software engineer
# 4  343523   200000.0  2014-03-01  2015-03-01                       get
#
#      JobCity Gender   DOB  10percentage                         10board  ...  \
# 0  Bangalore      f  1990          84.3  board ofsecondary education,ap  ...
# 1     Indore      m  1989          85.4                            cbse  ...
# 2    Chennai      f  1992          85.0                            cbse  ...
# 3    Gurgaon      m  1989          85.6                            cbse  ...
# 4    Manesar      m  1991          78.0                            cbse  ...
#
# ...

# %%
(df==0).astype(int).sum(axis=0)
# Out:
# ID                          0
# Salary                      0
# DOJ                         0
# DOL                         0
# Designation                 0
# JobCity                     0
# Gender                      0
# DOB                         0
# 10percentage                0
# 10board                     0
# 12graduation                0
# 12percentage                0
# 12board                     0
# CollegeID                   0
# CollegeTier                 0
# Degree                      0
# Specialization              0
# collegeGPA                  0
# CollegeCityID               0
# CollegeCityTier          2797
# CollegeState                0
# GraduationYear              1
# English                     0
# Logical                     0
# Quant                       0
# Domain                      0
# ComputerProgramming         0
# ElectronicsAndSemicon       0
# ComputerScience             0
# MechanicalEngg              0
# ElectricalEngg              0
# ...

# %%
df.isin([-1, 'NaN']).sum()
# Out:
# ID                          0
# Salary                      0
# DOJ                         0
# DOL                         0
# Designation                 0
# JobCity                     0
# Gender                      0
# DOB                         0
# 10percentage                0
# 10board                     0
# 12graduation                0
# 12percentage                0
# 12board                     0
# CollegeID                   0
# CollegeTier                 0
# Degree                      0
# Specialization              0
# collegeGPA                  0
# CollegeCityID               0
# CollegeCityTier             0
# CollegeState                0
# GraduationYear              0
# English                     0
# Logical                     0
# Quant                       0
# Domain                    246
# ComputerProgramming       868
# ElectronicsAndSemicon    2854
# ComputerScience          3096
# MechanicalEngg           3763
# ElectricalEngg           3837
# ...

# %%
df[df["Designation"]=="get"][['Designation','JobCity','Salary','Specialization']]
# Out:
#      Designation    JobCity     Salary  \
# 4            get    Manesar   200000.0
# 332          get         -1   180000.0
# 350          get  Faridabad   340000.0
# 1717         get  Hyderabad   145000.0
# 1897         get  Hyderabad   175000.0
# 2140         get     Indore   600000.0
# 2318         get    Lucknow   220000.0
# 2443         get  kharagpur   110000.0
# 2666         get  Hyderabad   200000.0
# 2757         get     Nashik   350000.0
# 3045         get  Sahibabad   180000.0
# 3126         get     Bhopal  1210000.0
# 3594         get     MEERUT   280000.0
# 3980         get    haryana   150000.0
#
#                                  Specialization
# 4     electronics and communication engineering
# 332                   mechanical and automation
# 350                      electrical engineering
# 1717                     mechanical engineering
# 1897                     mechanical engineering
# 2140                     mechanical engineering
# ...

# %% [markdown]
# from the above details we can clearly see that the people whose Designation is not mentioned is from Mechanical Backgroud and handful of them are from electronics and electrical engineering Background

# %%
df[df['Specialization'].isin(['mechanical engineering','mechanical and automation'])]['Designation'].mode()[0]
# Out:
# 'production engineer'

# %%
df[df['Specialization']==('electronics and electrical engineering')]['Designation'].mode()[0]
# Out:
# 'system engineer'

# %%
me = df[df['Specialization'].isin(['mechanical engineering','mechanical and automation'])]['Designation'].mode()[0]
eee = df[df['Specialization']==('electronics and electrical engineering')]['Designation'].mode()[0]

# %%
df.loc[df['Specialization'].isin(['mechanical engineering','mechanical and automation']),'Designation'].replace('get',me,inplace=True)

# %%
df['Designation'].replace('get',eee,inplace=True)

# %%
df[df["Designation"]=="get"][['Designation','JobCity','Salary','Specialization']]
# Out:
# Empty DataFrame
# Columns: [Designation, JobCity, Salary, Specialization]
# Index: []

# %%
df['JobCity'].replace("-1",'unknown',inplace=True)
df['JobCity'].apply(lambda x:x.title())
# Out:
# 0              Bangalore
# 1                 Indore
# 2                Chennai
# 3                Gurgaon
# 4                Manesar
#               ...
# 3993          New Delhi
# 3994           Hyderabad
# 3995           Bangalore
# 3996    Asifabadbanglore
# 3997             Chennai
# Name: JobCity, Length: 3998, dtype: object

# %%
df["JobCity"].unique()
# Out:
# array(['Bangalore', 'Indore', 'Chennai', 'Gurgaon', 'Manesar',
#        'Hyderabad', 'Banglore', 'Noida', 'Kolkata', 'Pune', 'unknown',
#        'mohali', 'Jhansi', 'Delhi', 'Hyderabad ', 'Bangalore ', 'noida',
#        'delhi', 'Bhubaneswar', 'Navi Mumbai', 'Mumbai', 'New Delhi',
#        'Mangalore', 'Rewari', 'Gaziabaad', 'Bhiwadi', 'Mysore', 'Rajkot',
#        'Greater Noida', 'Jaipur', 'noida ', 'HYDERABAD', 'mysore',
#        'THANE', 'Maharajganj', 'Thiruvananthapuram', 'Punchkula',
#        'Bhubaneshwar', 'Pune ', 'coimbatore', 'Dhanbad', 'Lucknow',
#        'Trivandrum', 'kolkata', 'mumbai', 'Gandhi Nagar', 'Una',
#        'Daman and Diu', 'chennai', 'GURGOAN', 'vsakhapttnam', 'pune',
#        'Nagpur', 'Bhagalpur', 'new delhi - jaisalmer', 'Coimbatore',
#        'Ahmedabad', 'Kochi/Cochin', 'Bankura', 'Bengaluru', 'Mysore ',
#        'Kanpur ', 'jaipur', 'Gurgaon ', 'bangalore', 'CHENNAI',
#        'Vijayawada', 'Kochi', 'Beawar', 'Alwar', 'NOIDA', 'Greater noida',
# ...

# %%
df[df["JobCity"]=='unknown']
# Out:
#            ID    Salary         DOJ         DOL  \
# 15     536517  350000.0  2013-08-01  2024-10-04
# 21     339689  200000.0  2012-08-01  2013-12-01
# 39     533417  200000.0  2013-01-01  2013-06-01
# 77     754392  120000.0  2014-07-01  2024-10-04
# 79    1089852  100000.0  2013-08-01  2014-05-01
# ...       ...       ...         ...         ...
# 3937   385546  205000.0  2012-10-01  2014-02-01
# 3942  1067015  280000.0  2013-07-01  2024-10-04
# 3954   531726  310000.0  2014-04-01  2015-04-01
# 3973   755067  335000.0  2013-08-01  2024-10-04
# 3974   641821  180000.0  2013-06-01  2014-07-01
#
#                         Designation  JobCity Gender   DOB  10percentage  \
# 15                 network engineer  unknown      f  1990         69.54
# 21                software engineer  unknown      f  1991         75.67
# 39               management trainee  unknown      m  1991         88.00
# 77                    test engineer  unknown      m  1992         76.00
# ...

# %%
df["JobCity"].replace("Bangalore","Bengaluru",inplace=True)
df["JobCity"].replace("Banaglore","Bengaluru",inplace=True)
df["JobCity"].replace("chennai","Chennai",inplace=True)
df["JobCity"].replace(" Bangalore","Bengaluru",inplace=True)
df["JobCity"].replace("Bangalore ","Bengaluru",inplace=True)
df["JobCity"].replace("Banglore","Bengaluru",inplace=True)
df["JobCity"].replace("Jaipur ","Jaipur",inplace=True)
df["JobCity"].replace("Gandhinagar","Gandhi Nagar",inplace=True)
df["JobCity"].replace("Bangalore ","Bengaluru",inplace=True)
df["JobCity"].replace("Jaipur ","Jaipur",inplace=True)
df["JobCity"].replace("Gandhinagar","Gandhi Nagar",inplace=True)
df["JobCity"].replace("Hyderabad ","Hyderabad",inplace=True)
df["JobCity"].replace("Hyderabad(Bhadurpally)","Hyderabad",inplace=True)
df["JobCity"].replace("Bhubaneswar ","Bhubaneswar",inplace=True)
df["JobCity"].replace("Delhi/Ncr","Delhi",inplace=True)
df["JobCity"].replace("Nagpur ","Nagpur",inplace=True)
df["JobCity"].replace("Pune ","Pune",inplace=True)
df["JobCity"].replace("Trivandrum ","Trivandrum",inplace=True)
df["JobCity"].replace("Thiruvananthapuram","Trivandrum",inplace=True)
df["JobCity"].replace("Delhi/NCR","Delhi",inplace=True)
df["JobCity"].replace("kolkata ","Kolkata",inplace=True)

# %%
df["JobCity"].unique()
# Out:
# array(['Bengaluru', 'Indore', 'Chennai', 'Gurgaon', 'Manesar',
#        'Hyderabad', 'Noida', 'Kolkata', 'Pune', 'unknown', 'mohali',
#        'Jhansi', 'Delhi', 'noida', 'delhi', 'Bhubaneswar', 'Navi Mumbai',
#        'Mumbai', 'New Delhi', 'Mangalore', 'Rewari', 'Gaziabaad',
#        'Bhiwadi', 'Mysore', 'Rajkot', 'Greater Noida', 'Jaipur', 'noida ',
#        'HYDERABAD', 'mysore', 'THANE', 'Maharajganj', 'Trivandrum',
#        'Punchkula', 'Bhubaneshwar', 'coimbatore', 'Dhanbad', 'Lucknow',
#        'kolkata', 'mumbai', 'Gandhi Nagar', 'Una', 'Daman and Diu',
#        'GURGOAN', 'vsakhapttnam', 'pune', 'Nagpur', 'Bhagalpur',
#        'new delhi - jaisalmer', 'Coimbatore', 'Ahmedabad', 'Kochi/Cochin',
#        'Bankura', 'Mysore ', 'Kanpur ', 'jaipur', 'Gurgaon ', 'bangalore',
#        'CHENNAI', 'Vijayawada', 'Kochi', 'Beawar', 'Alwar', 'NOIDA',
#        'Greater noida', 'Siliguri ', 'raipur', 'gurgaon', 'Bhopal',
# ...

# %%
best_mode = []
best_mode.append(df[df["Designation"]=="software engineer"]["JobCity"].mode().to_list()[0])
best_mode.append(df[df["Gender"]=="m"]["JobCity"].mode().to_list()[0])
best_mode.append(df[df["10percentage"]==76]["JobCity"].mode().to_list()[0])
best_mode.append(df[df["10board"]=="cbse"]["JobCity"].mode().to_list()[0])
best_mode.append(df[df["12percentage"]==64]["JobCity"].mode().to_list()[0])
best_mode.append(df[df["12board"]=="cbse"]["JobCity"].mode().to_list()[0])
best_mode.append(df[df["collegeGPA"]==70]["JobCity"].mode().to_list()[0])
best_mode.append(df[df["Salary"]==200000]["JobCity"].mode().to_list()[0])
best_mode.append(df[df["Degree"].str.startswith("B.Tech/")]["JobCity"].mode().to_list()[0])
best_mode.append(df[df["Specialization"].str.startswith("electronics and communication eng")]["JobCity"].mode().to_list()[0])
best_mode.append(df[df["CollegeState"].str.startswith("Uttar Pradesh")]["JobCity"].mode().to_list()[0])
best_mode
# Out:
# ['Bengaluru',
#  'Bengaluru',
#  'unknown',
#  'Noida',
#  'unknown',
#  'Noida',
#  'Bengaluru',
#  'unknown',
#  'Bengaluru',
#  'Bengaluru',
#  'Noida']

# %%
df["JobCity"].replace("unknown",'Bengaluru',inplace=True)

# %%
df["JobCity"].replace({"erroneous value":"correct value"}, inplace=True)

# %%
df["JobCity"].unique()
# Out:
# array(['Bengaluru', 'Indore', 'Chennai', 'Gurgaon', 'Manesar',
#        'Hyderabad', 'Noida', 'Kolkata', 'Pune', 'mohali', 'Jhansi',
#        'Delhi', 'noida', 'delhi', 'Bhubaneswar', 'Navi Mumbai', 'Mumbai',
#        'New Delhi', 'Mangalore', 'Rewari', 'Gaziabaad', 'Bhiwadi',
#        'Mysore', 'Rajkot', 'Greater Noida', 'Jaipur', 'noida ',
#        'HYDERABAD', 'mysore', 'THANE', 'Maharajganj', 'Trivandrum',
#        'Punchkula', 'Bhubaneshwar', 'coimbatore', 'Dhanbad', 'Lucknow',
#        'kolkata', 'mumbai', 'Gandhi Nagar', 'Una', 'Daman and Diu',
#        'GURGOAN', 'vsakhapttnam', 'pune', 'Nagpur', 'Bhagalpur',
#        'new delhi - jaisalmer', 'Coimbatore', 'Ahmedabad', 'Kochi/Cochin',
#        'Bankura', 'Mysore ', 'Kanpur ', 'jaipur', 'Gurgaon ', 'bangalore',
#        'CHENNAI', 'Vijayawada', 'Kochi', 'Beawar', 'Alwar', 'NOIDA',
#        'Greater noida', 'Siliguri ', 'raipur', 'gurgaon', 'Bhopal',
#        'Faridabad', 'Jodhpur', 'udaipur', 'Muzaffarpur', 'Kolkata`',
# ...

# %%
best_value2=[]
best_value2.append(df[df["Designation"]=="software engineer"]["10board"].mode().to_list()[0])
best_value2.append(df[df["Gender"]=="m"]["10board"].mode().to_list()[0])
best_value2.append(df[df["10percentage"]==75]["10board"].mode().to_list()[0])
best_value2.append(df[df["JobCity"]=="Bengaluru"]["10board"].mode().to_list()[0])
best_value2.append(df[df["12percentage"]==65]["10board"].mode().to_list()[0])
best_value2.append(df[df["collegeGPA"]==65]["10board"].mode().to_list()[0])
best_value2.append(df[df["Salary"]==400000]["10board"].mode().to_list()[0])
best_value2.append(df[df["Degree"].str.startswith("B.Tech/")]["10board"].mode().to_list()[0])
best_value2.append(df[df["Specialization"].str.startswith("computer eng")]["10board"].mode().to_list()[0])
best_value2.append(df[df["CollegeState"].str.startswith("Tamil Nadu")]["10board"].mode().to_list()[0])
best_value2
# Out:
# ['cbse',
#  'cbse',
#  'cbse',
#  'cbse',
#  'cbse',
#  'cbse',
#  'cbse',
#  'cbse',
#  'cbse',
#  'state board']

# %%
df['10board'].replace(0,'cbse',inplace=True)

# %%
df['12board'].replace(0,'cbse',inplace=True)

# %%
df.drop(['CollegeCityID','CollegeCityTier','ComputerProgramming','ElectronicsAndSemicon',
          'ComputerScience','MechanicalEngg','ElectricalEngg','TelecomEngg','CivilEngg'], axis=1, inplace=True)

# %%
df
# Out:
#           ID     Salary         DOJ         DOL                  Designation  \
# 0     203097   420000.0  2012-06-01  2024-10-04      senior quality engineer
# 1     579905   500000.0  2013-09-01  2024-10-04            assistant manager
# 2     810601   325000.0  2014-06-01  2024-10-04             systems engineer
# 3     267447  1100000.0  2011-07-01  2024-10-04     senior software engineer
# 4     343523   200000.0  2014-03-01  2015-03-01              system engineer
# ...      ...        ...         ...         ...                          ...
# 3993   47916   280000.0  2011-10-01  2012-10-01            software engineer
# 3994  752781   100000.0  2013-07-01  2013-07-01             technical writer
# 3995  355888   320000.0  2013-07-01  2024-10-04  associate software engineer
# 3996  947111   200000.0  2014-07-01  2015-01-01           software developer
# 3997  324966   400000.0  2013-02-01  2024-10-04      senior systems engineer
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeState', 'GraduationYear', 'English', 'Logical', 'Quant',
#        'Domain', 'conscientiousness', 'agreeableness', 'extraversion',
#        'nueroticism', 'openess_to_experience', 'Period'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Specialization"].value_counts()
# Out:
# Specialization
# electronics and communication engineering      880
# computer science & engineering                 744
# information technology                         660
# computer engineering                           600
# computer application                           244
# mechanical engineering                         201
# electronics and electrical engineering         196
# electronics & telecommunications               121
# electrical engineering                          82
# electronics & instrumentation eng               32
# civil engineering                               29
# electronics and instrumentation engineering     27
# information science engineering                 27
# instrumentation and control engineering         20
# electronics engineering                         19
# biotechnology                                   15
# other                                           13
# industrial & production engineering             10
# ...

# %%
 df["10board"].value_counts()
# Out:
# 10board
# cbse                          1395
# state board                   1164
# 0                              350
# icse                           281
# ssc                            122
#                               ...
# hse,orissa                       1
# national public school           1
# nagpur board                     1
# jharkhand academic council       1
# bse,odisha                       1
# Name: count, Length: 275, dtype: int64

# %%
df["Salary"].value_counts()
# Out:
# Salary
# 300000.0     293
# 180000.0     239
# 200000.0     205
# 325000.0     188
# 120000.0     165
#             ...
# 2050000.0      1
# 144000.0       1
# 1320000.0      1
# 755000.0       1
# 925000.0       1
# Name: count, Length: 177, dtype: int64

# %%
df["Salary"].unique()
# Out:
# array([ 420000.,  500000.,  325000., 1100000.,  200000.,  300000.,
#         400000.,  600000.,  230000.,  450000.,  270000.,  350000.,
#         250000.,  120000.,  320000.,  190000.,  180000.,  335000.,
#         435000.,  345000.,  145000.,  220000.,  530000.,  340000.,
#         360000.,  215000.,   80000.,  330000.,  380000.,  110000.,
#         205000.,   95000.,  390000.,   60000.,  240000.,  525000.,
#         305000.,  150000.,  310000.,  455000.,  800000.,  100000.,
#         280000.,  445000.,  315000.,  370000.,  275000., 1500000.,
#         425000.,  470000.,  460000.,  510000.,  480000.,  170000.,
#         640000.,  225000.,  440000., 1200000.,  675000.,  105000.,
#         195000.,  385000.,  235000.,  615000.,  290000.,  140000.,
#         405000., 1860000.,  375000.,  430000.,  660000.,   70000.,
#         410000.,  550000.,   35000.,  115000.,  415000.,  265000.,
#         285000.,  245000.,  395000.,  560000.,  700000.,  185000.,
# ...

# %% [markdown]
# ##### to standardized the outliers

# %%
from scipy.stats import zscore

# %%
z_scores = np.abs(zscore(df.select_dtypes(include=np.number)))
z_scores
# Out:
#             ID    Salary       DOB  10percentage  12graduation  12percentage  \
# 0     1.268535  0.527947  0.241881      0.647233      0.657765      1.939676
# 1     0.230991  0.904045  0.807731      0.758921      0.657765      0.957729
# 2     0.404233  0.081332  0.889820      0.718307      1.156686      0.569744
# 3     1.091347  3.724775  0.807731      0.779227      0.657765      0.830439
# 4     0.881871  0.506320  0.323970      0.007570      0.052948      0.212176
# ...        ...       ...       ...           ...           ...           ...
# 3993  1.695828  0.130223  1.939432      2.623172      1.262582      1.724441
# 3994  0.245025  0.976442  0.889820      1.225977      0.551869      1.685097
# 3995  0.847824  0.057826  0.323970      0.399491      0.052948      0.815231
# 3996  0.780115  0.506320  0.889820      0.080674      1.156686      0.416997
# 3997  0.932968  0.433923  0.323970      0.743781      0.052948      0.587929
#
# ...

# %%
df_no_outliers = df[(z_scores < 3).all(axis=1)]
df_no_outliers
# Out:
#           ID    Salary         DOJ         DOL                  Designation  \
# 0     203097  420000.0  2012-06-01  2024-10-04      senior quality engineer
# 1     579905  500000.0  2013-09-01  2024-10-04            assistant manager
# 2     810601  325000.0  2014-06-01  2024-10-04             systems engineer
# 4     343523  200000.0  2014-03-01  2015-03-01              system engineer
# 6     947847  300000.0  2014-08-01  2015-05-01       java software engineer
# ...      ...       ...         ...         ...                          ...
# 3993   47916  280000.0  2011-10-01  2012-10-01            software engineer
# 3994  752781  100000.0  2013-07-01  2013-07-01             technical writer
# 3995  355888  320000.0  2013-07-01  2024-10-04  associate software engineer
# 3996  947111  200000.0  2014-07-01  2015-01-01           software developer
# 3997  324966  400000.0  2013-02-01  2024-10-04      senior systems engineer
#
#                JobCity Gender   DOB  10percentage  \
# ...

# %% [markdown]
# ##### Remove duplicate and missing values

# %%
df = df.drop_duplicates()
df
# Out:
#           ID     Salary         DOJ         DOL                  Designation  \
# 0     203097   420000.0  2012-06-01  2024-10-04      senior quality engineer
# 1     579905   500000.0  2013-09-01  2024-10-04            assistant manager
# 2     810601   325000.0  2014-06-01  2024-10-04             systems engineer
# 3     267447  1100000.0  2011-07-01  2024-10-04     senior software engineer
# 4     343523   200000.0  2014-03-01  2015-03-01              system engineer
# ...      ...        ...         ...         ...                          ...
# 3993   47916   280000.0  2011-10-01  2012-10-01            software engineer
# 3994  752781   100000.0  2013-07-01  2013-07-01             technical writer
# 3995  355888   320000.0  2013-07-01  2024-10-04  associate software engineer
# 3996  947111   200000.0  2014-07-01  2015-01-01           software developer
# 3997  324966   400000.0  2013-02-01  2024-10-04      senior systems engineer
#
# ...

# %%
df = df.dropna()
df
# Out:
#           ID     Salary         DOJ         DOL                  Designation  \
# 0     203097   420000.0  2012-06-01  2024-10-04      senior quality engineer
# 1     579905   500000.0  2013-09-01  2024-10-04            assistant manager
# 2     810601   325000.0  2014-06-01  2024-10-04             systems engineer
# 3     267447  1100000.0  2011-07-01  2024-10-04     senior software engineer
# 4     343523   200000.0  2014-03-01  2015-03-01              system engineer
# ...      ...        ...         ...         ...                          ...
# 3993   47916   280000.0  2011-10-01  2012-10-01            software engineer
# 3994  752781   100000.0  2013-07-01  2013-07-01             technical writer
# 3995  355888   320000.0  2013-07-01  2024-10-04  associate software engineer
# 3996  947111   200000.0  2014-07-01  2015-01-01           software developer
# 3997  324966   400000.0  2013-02-01  2024-10-04      senior systems engineer
#
# ...

# %%
df['12graduation'].replace({'erroneous_value':'correct_value'},inplace=True)

# %%
df['12graduation'].unique()
# Out:
# array([2007, 2010, 2008, 2009, 2006, 2011, 2005, 1995, 2004, 2012, 2003,
#        2002, 2001, 1998, 2013, 1999], dtype=int64)

# %%
df.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeState', 'GraduationYear', 'English', 'Logical', 'Quant',
#        'Domain', 'conscientiousness', 'agreeableness', 'extraversion',
#        'nueroticism', 'openess_to_experience', 'Period'],
#       dtype='object')

# %% [markdown]
# ##### To normalize the salary column

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale =MinMaxScaler()
df[['Salary']] = scale.fit_transform(df[['Salary']])

# %%
df
# Out:
#           ID    Salary         DOJ         DOL                  Designation  \
# 0     203097  0.097100  2012-06-01  2024-10-04      senior quality engineer
# 1     579905  0.117276  2013-09-01  2024-10-04            assistant manager
# 2     810601  0.073140  2014-06-01  2024-10-04             systems engineer
# 3     267447  0.268600  2011-07-01  2024-10-04     senior software engineer
# 4     343523  0.041614  2014-03-01  2015-03-01              system engineer
# ...      ...       ...         ...         ...                          ...
# 3993   47916  0.061791  2011-10-01  2012-10-01            software engineer
# 3994  752781  0.016393  2013-07-01  2013-07-01             technical writer
# 3995  355888  0.071879  2013-07-01  2024-10-04  associate software engineer
# 3996  947111  0.041614  2014-07-01  2015-01-01           software developer
# 3997  324966  0.092055  2013-02-01  2024-10-04      senior systems engineer
#
#                JobCity Gender   DOB  10percentage  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3998 non-null   int64
#  1   Salary                 3998 non-null   float64
#  2   DOJ                    3998 non-null   object
#  3   DOL                    3998 non-null   object
#  4   Designation            3998 non-null   object
#  5   JobCity                3998 non-null   object
#  6   Gender                 3998 non-null   object
#  7   DOB                    3998 non-null   int32
#  8   10percentage           3998 non-null   float64
#  9   10board                3998 non-null   object
#  10  12graduation           3998 non-null   int64
#  11  12percentage           3998 non-null   float64
#  12  12board                3998 non-null   object
#  13  CollegeID              3998 non-null   int64
# ...

# %%
df['GraduationYear'].fillna(df['GraduationYear'].mode()[0], inplace = True)

# %%
df['Gender'].replace({'f':'Female','m':'Male'}, inplace = True)

# %%
df['Domain'].fillna(df['Domain'].median(), inplace = True)

# %%
specialization_map = \
{'electronics and communication engineering' : 'EC',
 'computer science & engineering' : 'CS',
 'information technology' : 'CS' ,
 'computer engineering' : 'CS',
 'computer application' : 'CS',
 'mechanical engineering' : 'ME',
 'electronics and electrical engineering' : 'EC',
 'electronics & telecommunications' : 'EC',
 'electrical engineering' : 'EL',
 'electronics & instrumentation eng' : 'EC',
 'civil engineering' : 'CE',
 'electronics and instrumentation engineering' : 'EC',
 'information science engineering' : 'CS',
 'instrumentation and control engineering' : 'EC',
 'electronics engineering' : 'EC',
 'biotechnology' : 'other',
 'other' : 'other',
 'industrial & production engineering' : 'other',
 'chemical engineering' : 'other',
 'applied electronics and instrumentation' : 'EC',
 'computer science and technology' : 'CS',
 'telecommunication engineering' : 'EC',
 'mechanical and automation' : 'ME',
 'automobile/automotive engineering' : 'ME',
 'instrumentation engineering' : 'EC',
 'mechatronics' : 'ME',
 'electronics and computer engineering' : 'CS',
 'aeronautical engineering' : 'ME',
 'computer science' : 'CS',
 'metallurgical engineering' : 'other',
 'biomedical engineering' : 'other',
 'industrial engineering' : 'other',
 'information & communication technology' : 'EC',
 'electrical and power engineering' : 'EL',
 'industrial & management engineering' : 'other',
 'computer networking' : 'CS',
 'embedded systems technology' : 'EC',
 'power systems and automation' : 'EL',
 'computer and communication engineering' : 'CS',
 'information science' : 'CS',
 'internal combustion engine' : 'ME',
 'ceramic engineering' : 'other',
 'mechanical & production engineering' : 'ME',
 'control and instrumentation engineering' : 'EC',
 'polymer technology' : 'other',
 'electronics' : 'EC'}

# %%
df['Specialization'] = df['Specialization'].map(specialization_map)
df['Specialization'].unique()
# Out:
# array(['CS', 'EC', 'ME', 'EL', 'CE', 'other'], dtype=object)

# %%
def correct_string_data(data):
    df[data] = df[data].str.lower().str.strip()

# %%
textual_columns = ['Designation','JobCity','10board','12board','Specialization','CollegeState']

# %%
for col in textual_columns:
    print(f'Number of unique values in {col} with inconsistency : {df[col].nunique()}')
# Out:
# Number of unique values in Designation with inconsistency : 418
# Number of unique values in JobCity with inconsistency : 324
# Number of unique values in 10board with inconsistency : 275
# Number of unique values in 12board with inconsistency : 340
# Number of unique values in Specialization with inconsistency : 46
# Number of unique values in CollegeState with inconsistency : 26

# %%
for col in textual_columns:
    correct_string_data(col)

# %%
for col in textual_columns:
    print(f'Number of unique values in {col} without inconsistency : {df[col].nunique()}')
# Out:
# Number of unique values in Designation without inconsistency : 418
# Number of unique values in JobCity without inconsistency : 228
# Number of unique values in 10board without inconsistency : 273
# Number of unique values in 12board without inconsistency : 337
# Number of unique values in Specialization without inconsistency : 46
# Number of unique values in CollegeState without inconsistency : 26

# %%
city_mapping = {
 'Bengaluru': 'Bangalore',
 'delhi': 'Delhi',
 'Chennai':'Chennai',
 'Pune':'Pune',
 'asifabadbangalore' : 'Bangalore',
 'indore': 'Indore',
 'gurgaon':' Gurgaon',
 'gurgoan': 'Gurgaon',
 'gurga' : 'Gurgaon',
 'hyderabad' : 'Hyderabad',
 'hderabad' :'Hyderabad',
 'noida' : 'Noida',
 'nouda' :'Noida',
 'kolkata' :'Kolkata',
 'kolkata`' :'Kolkata',
 '-1' : 'Unknown',
 'mohali' :' Mohali',
 'jhansi' : 'Jhansi',
 'new delhi' : 'New Delhi',
 'mumbai' : 'Mumbai',
 'bhubaneswar' : 'Bhubaneswar',
 'bhubaneshwar' : 'Bhubaneswar',
 'navi mumbai' : 'Navi Mumbai',
  'mangalore': 'Mangalore',
 'rewari' : 'Rewari',
 'gaziabaad' : 'Ghaziabad',
 'ghaziabad' :'Ghaziabad',
 'bhiwadi':'Bhiwadi',
 'mysore' : 'Mysore',
 'rajkot': 'Rajkot',
 'greater noida': 'Greater Noida',
 'jaipur': 'Jaipur',
 'thane': 'Thane',
 'maharajganj': 'Maharajganj',
 'thiruvananthapuram': 'Thiruvananthapuram',
 'punchkula': 'Panchkula',
 'coimbatore': 'Coimbatore',
 'dhanbad': 'Dhanbad',
 'lucknow': 'Lucknow',
 'trivandrum': 'Thiruvananthapuram',
 'gandhi nagar': 'Gandhinagar',
 'una': 'Una',
 'daman and diu': 'Daman and Diu',
 'vsakhapttnam': 'Visakhapatnam',
  'nagpur': 'Nagpur',
 'bhagalpur': 'Bhagalpur',
 'new delhi - jaisalmer': 'New Delhi',
 'ahmedabad': 'Ahmedabad',
 'kochi/cochin': 'Kochi',
 'bankura': 'Bankura',
 'kanpur': 'Kanpur',
 'vijayawada': 'Vijayawada',
 'kochi': 'Kochi',
 'beawar': 'Beawar',
 'alwar': 'Alwar',
 'siliguri': 'Siliguri',
 'raipur': 'Raipur',
 'bhopal': 'Bhopal',
 'faridabad': 'Faridabad',
 'jodhpur': 'Jodhpur',
 'udaipur': 'Udaipur',
 'muzaffarpur': 'Muzaffarpur',
 'bulandshahar': 'Bulandshahar',
 'haridwar': 'Haridwar',
 'raigarh': 'Raigarh',
 'visakhapatnam': 'Visakhapatnam',
 'jabalpur': 'Jabalpur',
 'unnao': 'Unnao',
 'aurangabad': 'Aurangabad',
 'belgaum': 'Belgaum',
 'dehradun': 'Dehradun',
 'rudrapur': 'Rudrapur',
 'jamshedpur': 'Jamshedpur',
 'vizag': 'Visakhapatnam',
 'nouda': 'Noida',
 'dharamshala': 'Dharamshala',
 'hissar': 'Hisar',
 'ranchi': 'Ranchi',
 'madurai': 'Madurai',
 'chandigarh': 'Chandigarh',
  'australia': 'Australia',
 'cheyyar': 'Cheyyar',
 'sonepat': 'Sonepat',
 'pantnagar': 'Pantnagar',
 'jagdalpur': 'Jagdalpur',
 'angul': 'Angul',
 'baroda': 'Vadodara',
 'ariyalur': 'Ariyalur',
 'jowai': 'Jowai',
 'neemrana': 'Neemrana',
 'tirupathi': 'Tirupati',
 'bhubneshwar': 'Bhubaneswar',
 'calicut': 'Kozhikode',
 'gandhinagar': 'Gandhinagar',
  'dubai': 'Dubai',
 'ahmednagar': 'Ahmednagar',
 'nashik': 'Nashik',
 'bellary': 'Bellary',
 'ludhiana': 'Ludhiana',
 'muzaffarnagar': 'Muzaffarnagar',
 'gagret': 'Gagret',
 'indirapuram, ghaziabad': 'Ghaziabad',
 'gwalior': 'Gwalior',
 'chennai & mumbai': 'Chennai',
  'rajasthan': 'Rajasthan',
 'sonipat': 'Sonipat',
 'bareli': 'Bareli',
 'hospete': 'Hospete',
 'miryalaguda': 'Miryalaguda',
 'dharuhera': 'Dharuhera',
 'meerut': 'Meerut',
 'ganjam': 'Ganjam',
 'hubli': 'Hubli',
 'ncr': 'NCR',
 'agra': 'Agra',
 'trichy': 'Tiruchirappalli',
 'kudankulam ,tarapur': 'Kudankulam',
 'ongole': 'Ongole',
 'sambalpur': 'Sambalpur',
 'pondicherry': 'Puducherry',
 'bundi': 'Bundi',
 'sadulpur,rajgarh,distt-churu,rajasthan': 'Rajasthan',
 'am': 'Am',
 'bikaner': 'Bikaner',
 'vadodara': 'Vadodara',
 'india': 'India',
 'asansol': 'Asansol',
 'tirunelvelli': 'Tirunelveli',
 'ernakulam': 'Ernakulam',
 'bilaspur': 'Bilaspur',
 'chandrapur': 'Chandrapur',
 'nanded': 'Nanded',
 'dharmapuri': 'Dharmapuri',
 'vandavasi': 'Vandavasi',
 'rohtak': 'Rohtak',
 'patna': 'Patna',
 'salem': 'Salem',
 'nasikcity': 'Nashik',
 'technopark, trivandrum': 'Trivandrum',
 'bharuch': 'Bharuch',
 'tornagallu': 'Tornagallu',
 'jaspur': 'Jaspur',
 'burdwan': 'Burdwan',
  'burdwan': 'Burdwan',
 'shimla': 'Shimla',
 'gajiabaad': 'Ghaziabad',
 'jammu': 'Jammu',
 'shahdol': 'Shahdol',
 'muvattupuzha': 'Muvattupuzha',
 'al jubail,saudi arabia': 'Al Jubail',
 'kalmar, sweden': 'Kalmar',
 'secunderabad': 'Secunderabad',
 'a-64,sec-64,noida': 'Noida',
 'ratnagiri': 'Ratnagiri',
 'jhajjar': 'Jhajjar',
 'gulbarga': 'Gulbarga',
 'hyderabad(bhadurpally)': 'Hyderabad',
  'nalagarh': 'Nalagarh',
 'jeddah saudi arabia': 'Jeddah',
 'chennai, bangalore': 'Chennai',
 'jamnagar': 'Jamnagar',
 'tirupati': 'Tirupati',
 'gonda': 'Gonda',
 'orissa': 'Odisha',
 'kharagpur': 'Kharagpur',
 'navi mumbai , hyderabad': 'Navi Mumbai',
 'joshimath': 'Joshimath',
 'bathinda': 'Bathinda',
 'johannesburg': 'Johannesburg','kala amb': 'Kala Amb',
 'karnal': 'Karnal',
 'london': 'London',
 'kota': 'Kota',
 'dehraj': 'Dehradun',
 'melbourne': 'Melbourne',
 'moradabad': 'Moradabad',
 'delhi-gurgaon': 'Delhi',
 'ambala': 'Ambala',
 'faridkot': 'Faridkot',
 'rohtak, haryana': 'Rohtak',
 'khammam': 'Khammam',
 'khurda': 'Khurda',
 'jhalawar': 'Jhalawar',
 'kaithal': 'Kaithal',
 'sonbhadra': 'Sonbhadra',
 'fatehgarh sahib': 'Fatehgarh Sahib',
 'kaithal-haryana': 'Kaithal',
 'bhilwara': 'Bhilwara',
 'coimbatore, tirupur': 'Coimbatore',
 'kala amb': 'Kala Amb',
 'karnal': 'Karnal',
 'london': 'London',
 'kota': 'Kota',
 'dehraj': 'Dehradun',
 'melbourne': 'Melbourne',
 'moradabad': 'Moradabad',
 'delhi-gurgaon': 'Delhi',
 'ambala': 'Ambala',
 'faridkot': 'Faridkot',
 'rohtak, haryana': 'Rohtak',
 'khammam': 'Khammam',
 'khurda': 'Khurda',
 'jhalawar': 'Jhalawar',
 'kaithal': 'Kaithal',
 'sonbhadra': 'Sonbhadra',
 'fatehgarh sahib': 'Fatehgarh Sahib',
 'kaithal-haryana': 'Kaithal',
 'bhilwara': 'Bhilwara',
 'coimbatore, tirupur': 'Coimbatore',
  'trichy-tiruchirappalli': 'Tiruchirappalli',
}

# %%
df["JobCity"] = df["JobCity"].map(city_mapping)

# %% [markdown]
# ### Univariate Analysis

# %%
sns.countplot(df['Gender'])
print(df['Gender'].value_counts())
# Out:
# Gender
# Male      3041
# Female     957
# Name: count, dtype: int64

# %% [markdown]
# ##### from the above countplot we can say that majority of the employees are Male from the total number of employees and count of female employee is very less compared to Male Employees.

# %%
grid = sns.FacetGrid(df, col="Gender", height=5)
grid.map_dataframe(sns.histplot, x="Salary", kde=True) 
plt.show()

# %% [markdown]
# ##### We can observe that the salary data is right skewed for both Male and Female

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='Salary',y='Gender',data=df)
# Out:
# <Axes: xlabel='Salary', ylabel='Gender'>

# %% [markdown]
# ##### It is noted that there are many outliers in the salary data where male have more outliers indicating there are more people getting higher pay in male than female category

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='Salary',y='Specialization',data=df)
plt.suptitle('Salary levels by specialization')
# Out:
# Text(0.5, 0.98, 'Salary levels by specialization')

# %% [markdown]
# ##### there are more people getting higher pays who have specialization in CS and EC compared to others.

# %%
popular_Designation = df['Designation'].value_counts()[:20].index.tolist()
print(popular_Designation)
# Out:
# ['software engineer', 'software developer', 'system engineer', 'programmer analyst', 'systems engineer', 'java software engineer', 'software test engineer', 'project engineer', 'technical support engineer', 'senior software engineer', 'java developer', 'test engineer', 'web developer', 'application developer', 'assistant manager', 'network engineer', 'data analyst', 'business analyst', 'engineer', 'associate software engineer']

# %%
top_Designations = df[df['Designation'].isin(popular_Designation)]
print(f"Unique professions : {len(df['Designation'].unique())}")
top_Designations.head()
# Out:
# Unique professions : 418
#         ID    Salary         DOJ         DOL               Designation  \
# 1   579905  0.117276  2013-09-01  2024-10-04         assistant manager
# 2   810601  0.073140  2014-06-01  2024-10-04          systems engineer
# 3   267447  0.268600  2011-07-01  2024-10-04  senior software engineer
# 4   343523  0.041614  2014-03-01  2015-03-01           system engineer
# 5  1027655  0.066835  2014-06-01  2024-10-04           system engineer
#
#      JobCity  Gender   DOB  10percentage      10board  ...  English  Logical  \
# 1     Indore    Male  1989         85.40         cbse  ...      695      610
# 2    Chennai  Female  1992         85.00         cbse  ...      615      545
# 3    Gurgaon    Male  1989         85.60         cbse  ...      635      585
# 4    Manesar    Male  1991         78.00         cbse  ...      545      625
# 5  Hyderabad    Male  1992         89.92  state board  ...      560      555
#
# ...

# %%
sns.countplot(y='Designation',hue='Gender',data=top_Designations)
plt.show()

# %% [markdown]
# ##### In all the professions the jobs are mainly dominated by Male

# %%
sns.countplot(df['Specialization'])
# Out:
# <Axes: xlabel='count', ylabel='Specialization'>

# %%
sns.countplot(df['Degree'])
# Out:
# <Axes: xlabel='count', ylabel='Degree'>

# %%
sns.barplot(y='Designation',x='Salary',hue='Gender',data=top_Designations)
plt.show()

# %% [markdown]
# - from the above three plots we can conclude that most of the employees are from CS back ground and they are BTech graduate
# - from the above barplot we can conclude that in all the designations male are not dominating with respect to salary, female employees are also getting better salary in some designations

# %%
high = list(df.sort_values("Salary",ascending=False)["Designation"].unique())[:20]
high_pay = df[df['Designation'].isin(high)]
high_pay.head()
# Out:
#          ID    Salary         DOJ         DOL               Designation  \
# 3    267447  0.268600  2011-07-01  2024-10-04  senior software engineer
# 6    947847  0.066835  2014-08-01  2015-05-01    java software engineer
# 14  1279958  0.066835  2013-07-01  2024-10-04    java software engineer
# 19   466888  0.073140  2014-09-01  2024-10-04         software engineer
# 20   140069  0.071879  2010-11-01  2012-09-01         software engineer
#
#       JobCity  Gender   DOB  10percentage  \
# 3     Gurgaon    Male  1989         85.60
# 6   Bengaluru    Male  1993         86.08
# 14  Bengaluru    Male  1992         81.20
# 19       Pune  Female  1990         79.00
# 20  Bengaluru  Female  1988         91.20
#
#                                       10board  ...  English  Logical Quant  \
# 3                                        cbse  ...      635      585   625
# 6                                 state board  ...      590      435   380
# ...

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=high_pay,x='Period',y='Salary',hue='Gender')
# Out:
# <Axes: xlabel='Period', ylabel='Salary'>

# %% [markdown]
# ##### The median salaries for both genders show a slight increase in the first five years, followed by a sudden drop in the sixth year, indicating that men and women with similar experience earn approximately equal salaries (3.5-5 lakhs), necessitating a further examination of the experience distribution concerning designation to determine if women are underpaid relative to their experience in specific roles.

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=high_pay,y='Designation',x='Period',hue='Gender')
plt.show()

# %% [markdown]
# ##### The analysis reveals that while experience varies among designations, and there are median experience differences between genders, the lack of a strong correlation between experience and salary, alongside instances where women with higher experience earn less than men, suggests that salary disparities cannot be solely attributed to experience levels.

# %%
sns.histplot(data=df, x="10percentage")
plt.show()

# %% [markdown]
# ##### Most of the employees passed with around 88 percentage in 10th standard

# %%
sns.countplot(data=df, x="GraduationYear")
plt.show()

# %% [markdown]
# ##### As per the above plot we can conclude that most of the employees did their graduation in 2013 year.

# %%
sns.histplot(df["collegeGPA"], kde=True)
plt.xlabel('collegeGPA')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ##### College GPA of the employees are around 60 to 75

# %%
df['12graduation'].values
# Out:
# array([2007, 2007, 2010, ..., 2008, 2010, 2008], dtype=int64)

# %%
df['12graduation'].plot(kind = "kde")	
plt.xlabel('12graduation')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ##### The highest number of employees 12th graduated around the year 2009 - 2010.

# %%
sns.histplot(df['12percentage'],kde=True)		
plt.xlabel('12percentage')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ##### Most of the employees passed with 70-80 percentage in the 12th grade

# %%
selected_columns=['ID','Salary','Logical','Quant','conscientiousness']
fig,axes = plt.subplots(nrows=len(selected_columns),ncols=1,figsize=(5,5*len(selected_columns)))
for i,column in enumerate(selected_columns):
    ax = axes[i]
    sns.boxplot(x=df[column],ax=ax)
    ax.set_title(f'Boxplot of {column}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### The boxplot analysis shows that the "ID" variable has no outliers, indicating a reliable median. The "Salary" variable displays right-side outliers and a positive skew, suggesting extreme high values. The "Logical" variable has an asymmetric distribution with differing outliers on each side, a median of 505, and an IQR of 120. The "Quant" variable exhibits a symmetric distribution with outliers on both sides, a median of 515, and an IQR of 165. Lastly, the "Conscientiousness" variable has left-side outliers and a negative skew, indicating extreme low values.

# %%
df.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeState', 'GraduationYear', 'English', 'Logical', 'Quant',
#        'Domain', 'conscientiousness', 'agreeableness', 'extraversion',
#        'nueroticism', 'openess_to_experience', 'Period'],
#       dtype='object')

# %%
df_top_Jobcity = df['JobCity'].value_counts().nlargest(10).index
filtered_df = df[df['JobCity'].isin(df_top_Jobcity)]
sns.countplot(y='JobCity', data=filtered_df, order=df_top_Jobcity)
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
df_numeric = df.select_dtypes(include='number')

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(df_numeric.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
num_cols_3 = ['12graduation', '10percentage', '12percentage', 'collegeGPA', 
               'English', 'GraduationYear', 'Logical', 'Quant', 'Salary']

# Calculate number of rows and columns for subplots
num_rows = len(num_cols_3) // 3 + (len(num_cols_3) % 3 > 0)  # Adjusted to handle odd lengths
num_cols = 3

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(25, 25))
if num_rows == 1:
    axes = [axes]  # Ensure axes is a list for consistency

# Set color palette
colors = sns.color_palette('dark', len(num_cols_3))

# Create scatter plots
for i, col_name in enumerate(num_cols_3):
    row = i // num_cols
    col = i % num_cols
    sns.scatterplot(x=col_name, y='Salary', data=df, ax=axes[row][col], color=colors[i])
    axes[row][col].set_xlabel(col_name, fontsize=20)
    axes[row][col].set_ylabel('Salary', fontsize=20)

# %%
# Define the numerical columns for the pair plot
numerical_columns = ['Salary', '10percentage', '12percentage', 'collegeGPA', 'GraduationYear']

# Create the pair plot
sns.pairplot(df, vars=numerical_columns)

# Add a title to the figure
plt.suptitle('Pair Plot for Numerical Columns', y=1.02)
# Out:
# Text(0.5, 1.02, 'Pair Plot for Numerical Columns')

# %% [markdown]
# Times of India article dated Jan 18, 2019 states that “After doing your Computer Science Engineering if you take up jobs as a
# Programming	Analyst, Software Engineer, Hardware Engineer and Associate	Engineer you can earn upto 2.5-3 lakhs as a fresh graduate.
# Test this claim	with the data given to you.

# %%
sns.swarmplot(data = df, x= 'Degree', y	= 'Salary')
# Out:
# <Axes: xlabel='Degree', ylabel='Salary'>

# %%
# Filter data for those who have 'CS' degree
cse_data = df[df['Specialization'] == 'CS']

# List of relevant job roles
job_roles = ['Programming Analyst', 'Software Engineer', 'Hardware Engineer', 'Associate Engineer']

# Filter data for relevant designations
req_data = cse_data[cse_data['Designation'].isin(job_roles)]

# Define the salary range
salary_range = (250000, 300000)

# Calculate the average salary for the filtered data
avg_sal = req_data['Salary'].mean()

# Check if the average salary is within the defined range
if salary_range[0] <= avg_sal <= salary_range[1]:
    print('The claim is supported by the data')
else:
    print('The claim is not supported by the data')
# Out:
# The claim is not supported by the data

# %%
from scipy import stats

# Create a contingency table for Gender and Designation
contingency_table = pd.crosstab(df['Gender'], df['Specialization'])

# Perform the Chi-square test for independence
chi2_stats, p_val, dof, expected = stats.chi2_contingency(contingency_table)

# Set the significance level
alpha = 0.05

# Check if the p-value is less than the significance level (alpha)
if p_val < alpha:
    print("There is a significant relationship between gender and specialization preference.")
else:
    print("There is no significant relationship between gender and specialization preference.")
# Out:
# There is a significant relationship between gender and specialization preference.

# %% [markdown]
# **Observation:** Based on the analysis, the claim of a salary range between ₹2.5-3 lakhs for Computer Science graduates in specific job roles is not supported by the data. Additionally, the statistical test shows significant relationship between gender and specialization preference in the AMCAT dataset.

# %% [markdown]
# **Conclusion:** The dataset includes employment outcomes of engineering graduates (Salary, Job Titles, and Locations) and scores in cognitive, technical, and personality skills. The dataset contains 4000 rows and 40 columns with many duplicates, so it first needs cleaning, including removing unwanted rows and checking for missing values.
#
# We performed univariate analysis with plots like PDFs, histograms, boxplots, and countplots to identify outliers and frequency distributions in the data. Additionally, bivariate analysis was done using scatter plots, pair plots, barplots etc to examine relationships between numerical and categorical columns.
#
# Through these analyses, we explored relationships between employees' salaries and their backgrounds, such as graduation year, designation, and academic performance (10th and 12th percentages).
